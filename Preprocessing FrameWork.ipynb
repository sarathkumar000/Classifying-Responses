# %% [markdown]
# <a href="https://colab.research.google.com/github/sarathkumar000/Preprocessing/blob/master/Preprocessing%20FrameWork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import io
from google.colab import files
# !pip install emoji
# !pip install pyspellchecker
import pandas as pd
import numpy as np
import re
import string
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.corpus import wordnet
from nltk.stem.wordnet import WordNetLemmatizer
from spellchecker import SpellChecker
from emoji.unicode_codes import UNICODE_EMOJI
# Out:
# Requirement already satisfied: emoji in /usr/local/lib/python3.6/dist-packages (0.5.4)
# Requirement already satisfied: pyspellchecker in /usr/local/lib/python3.6/dist-packages (0.5.3)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
uploaded = files.upload()
df = pd.read_csv(io.StringIO(uploaded['TotalData.csv'].decode('cp1252')),)
df.head()
# Out:
#      <input type="file" id="files-c5b1f042-b443-40bd-9040-78fe70981ea8" name="files[]" multiple disabled />
#      <output id="result-c5b1f042-b443-40bd-9040-78fe70981ea8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving TotalData.csv to TotalData (1).csv
#    Valid                                             Review
# 0    1.0  Something is definitely wrong.  Get in touch w...
# 1    1.0  Shaking is most often a sign of pain distress,...
# 2    0.0  You had time to tell us about it and not take ...
# 3    0.0  Happy New year to be!!!! ?\nI'll take a tall g...
# 4    0.0  Happy New Year Otis and Blurtit family. I rais...

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                       "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not", 
                       "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", 
                       "how's": "how is",  "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", 
                       "I've": "I have", "i'd": "i would", "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", 
                       "i've": "i have", "isn't": "is not", "it'd": "it would", "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have",
                       "it's": "it is", "let's": "let us", "ma'am": "madam", "mayn't": "may not", "might've": "might have","mightn't": "might not",
                       "mightn't've": "might not have", "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", 
                       "needn't've": "need not have","o'clock": "of the clock", "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", 
                       "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", "she'll": "she will", 
                       "she'll've": "she will have", "she's": "she is", "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", 
                       "so've": "so have","so's": "so as", "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", 
                       "there'd": "there would", "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", 
                       "they'd've": "they would have", "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", 
                       "to've": "to have", "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", 
                       "we're": "we are", "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",  
                       "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is", 
                       "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have", "why's": "why is", 
                       "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have", "would've": "would have", "wouldn't": "would not", 
                       "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would","y'all'd've": "you all would have",
                       "y'all're": "you all are","y'all've": "you all have","you'd": "you would", "you'd've": "you would have", "you'll": "you will", 
                       "you'll've": "you will have", "you're": "you are", "you've": "you have" }

dic = {'colour': 'color', 'centre': 'center', 'favourite': 'favorite', 'travelling': 'traveling', 'counselling': 'counseling', 'theatre': 'theater', 
                'cancelled': 'canceled', 'labour': 'labor', 'organisation': 'organization', 'wwii': 'world war 2', 'citicise': 'criticize', 
                'youtu ': 'youtube ', 'Qoura': 'Quora', 'sallary': 'salary', 'Whta': 'What', 'narcisist': 'narcissist', 'howdo': 'how do', 
                'whatare': 'what are', 'howcan': 'how can', 'howmuch': 'how much', 'howmany': 'how many', 'whydo': 'why do', 'doI': 'do I', 
                'theBest': 'the best', 'howdoes': 'how does', 'mastrubation': 'masturbation', 'mastrubate': 'masturbate', "mastrubating": 'masturbating', 
                'pennis': 'penis', 'Etherium': 'Ethereum', 'narcissit': 'narcissist', 'bigdata': 'big data', '2k17': '2017', '2k18': '2018', 'qouta': 'quota', 
                'exboyfriend': 'ex boyfriend', 'airhostess': 'air hostess', "whst": 'what', 'watsapp': 'whatsapp', 'demonitisation': 'demonetization', 
                'demonitization': 'demonetization', 'demonetisation': 'demonetization'}

CHAT_WORDS = """
AFAIK=As Far As I Know
AFK=Away From Keyboard
ASAP=As Soon As Possible
ATK=At The Keyboard
ATM=At The Moment
A3=Anytime, Anywhere, Anyplace
BAK=Back At Keyboard
BBL=Be Back Later
BBS=Be Back Soon
BFN=Bye For Now
B4N=Bye For Now
BRB=Be Right Back
BRT=Be Right There
BTW=By The Way
B4=Before
B4N=Bye For Now
CU=See You
CUL8R=See You Later
CYA=See You
FAQ=Frequently Asked Questions
FC=Fingers Crossed
FWIW=For What It's Worth
FYI=For Your Information
GAL=Get A Life
GG=Good Game
GN=Good Night
GMTA=Great Minds Think Alike
GR8=Great!
G9=Genius
IC=I See
ICQ=I Seek you (also a chat program)
ILU=ILU: I Love You
IMHO=In My Honest/Humble Opinion
IMO=In My Opinion
IOW=In Other Words
IRL=In Real Life
KISS=Keep It Simple, Stupid
LDR=Long Distance Relationship
LMAO=Laugh My A.. Off
LOL=Laughing Out Loud
LTNS=Long Time No See
L8R=Later
MTE=My Thoughts Exactly
M8=Mate
NRN=No Reply Necessary
OIC=Oh I See
PITA=Pain In The A..
PRT=Party
PRW=Parents Are Watching
ROFL=Rolling On The Floor Laughing
ROFLOL=Rolling On The Floor Laughing Out Loud
ROTFLMAO=Rolling On The Floor Laughing My A.. Off
SK8=Skate
STATS=Your sex and age
ASL=Age, Sex, Location
THX=Thank You
TTFN=Ta-Ta For Now!
TTYL=Talk To You Later
U=You
U2=You Too
U4E=Yours For Ever
WB=Welcome Back
WTF=What The F...
WTG=Way To Go!
WUF=Where Are You From?
W8=Wait...
7K=Sick:-D Laugher
"""
chat_words_map_dict = {}
chat_words_list = []
for line in CHAT_WORDS.split("\n"):
      if line != "":
          cw = line.split("=")[0]
          cw_expanded = line.split("=")[1]
          chat_words_list.append(cw)
          chat_words_map_dict[cw] = cw_expanded
chat_words_list = set(chat_words_list)

# %%
# Our Framework starts here
def frameWork(text):
  return removeUrls(text)

# Method:1 Here We are removing URLS 
def removeUrls(text):
  url_pattern = re.compile(r'https?://\S+|www\.\S+')
  text=url_pattern.sub(r'', str(text))
  return removeHtmlTags(text)
# Method:2 Here we are removing Html Tags
def removeHtmlTags(text):
  html_pattern = re.compile('<.*?>')
  text=html_pattern.sub(r'', text)
  return removeAndReplaceEmojiEmoti(text)
from spellchecker import SpellChecker
# Method:3 Here We are removing and replacing emojis
def removeAndReplaceEmojiEmoti(inputString):
  text = ""
  for character in inputString:
        try:
            character.encode("ascii")
            text += character
        except UnicodeEncodeError:
            replaced = unidecode(str(character))
            if replaced != '':
                text += replaced
            else:
                try:
                     text += unicodedata.name(character) 
                except ValueError:
                     text += "[x]"
  for emot in EMOTICONS:
        text = re.sub(u'('+emot+')', "_".join(EMOTICONS[emot].replace(",","").split()), text)
    
  #text=emoticon_pattern.sub(r'',text)
  
  return clean_contractions(text)
#Method:4 Clearing contractions
def clean_contractions(text):
  specials = ["’", "‘", "´", "`"]
  for s in specials:
      text = text.replace(s, "'")
  text = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in text.split(" ")])
  
  return chatWordsConversion(text)
#Method:5 Chat words Conversion
def chatWordsConversion(text):
  new_text = []
  for w in text.split():
      if w.upper() in chat_words_list:
          new_text.append(chat_words_map_dict[w.upper()])
      else:
          new_text.append(w)
  text=" ".join(new_text)
  
  return replaceRepetitionPunc(text)

#Method 6: We are replacing repetitive punctuation
def replaceRepetitionPunc(text):
  """ Replaces repetitions of exlamation marks """
  text = re.sub(r"(\!)\1+", '', text)
    
  """ Replaces repetitions of question marks """
  text = re.sub(r"(\?)\1+", '', text)
    
  """ Replaces repetitions of stop marks """
  text = re.sub(r"(\.)\1+", '', text)
  
  return dealSpecialChars(text)
#Method:7 Here We are dealing with special Characters
def dealSpecialChars(text):
  punct = "/-'?!.,#$%\'()*+-/:;<=>@[\\]^_`{|}~" + '""“”’' + '∞θ÷α•à−β∅³π‘₹´°£€\×™√²—–&'
  mapping = {"‘": "'", "₹": "e", "´": "'", "°": "", "€": "e", "™": "tm", "√": " sqrt ", 
                   "×": "x", "²": "2", "—": "-", "–": "-", "’": "'", "_": "-", "`": "'", '“': '"', '”': '"', '“': '"', "£": "e", '∞': 'infinity', 
                   'θ': 'theta', '÷': '/', 'α': 'alpha', '•': '.', 'à': 'a', '−': '-', 'β': 'beta', '∅': '', '³': '3', 'π': 'pi', }
  #  We use a map to replace unknown characters with known ones.
  for p in mapping:
    text = text.replace(p, mapping[p])
  #We use a map to replace unknown characters with known ones.

  # We make sure there are spaces between words and punctuation
    
  for p in punct:
        text = text.replace(p, f' {p} ')
  
  return removePunc(text)
#Method:8 Here We are Removing Punctuation
def removePunc(text):
  translator = str.maketrans('', '', string.punctuation)
  text=text.translate(translator)
  
  return tokenize1(text)


#Method:9 From Here Onwards Replacing Negations with Antonyms

def tokenize1(text):
  tokens = nltk.word_tokenize(text)
  tokens = replaceNegations(tokens)
  text = " ".join(tokens)
  
  return removeNum(text)
def replaceNegations(text):
  """ Finds "not" and antonym for the next word and if found, replaces not and the next word with the antonym """
  i, l = 0, len(text)
  words = []
  while i < l:
      word = text[i]
      if word == 'not' and i+1 < l:
          ant = replace(text[i+1])
          if ant:
              words.append(ant)
              i += 2
              continue
      words.append(word)
      i += 1
  return words
def replace(word, pos=None):
    """ Creates a set of all antonyms for the word and if there is only one antonym, it returns it """
    antonyms = set()
    for syn in wordnet.synsets(word, pos=pos):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                antonyms.add(antonym.name())
    if len(antonyms) == 1:
        return antonyms.pop()
    else:
        return None

#Method:10 this method is for removing Numbers
def removeNum(text):
  text = ''.join([i for i in text if not i.isdigit()]) 
          
  return lower(text)

#Method:11 Here we are converting string to lower
def lower(text):
  text=text.lower()
  
  return tokenize(text)

#Method:12 From Here Replacing Elongated Words superrrrrrrrrrr -> super 
def replaceElongated(word):
    """ Replaces an elongated word with its basic form, unless the word exists in the lexicon """

    repeat_regexp = re.compile(r'(\w*)(\w)\2(\w*)')
    repl = r'\1\2\3'
    if wordnet.synsets(word):
        return word
    repl_word = repeat_regexp.sub(repl, word)
    if repl_word != word:      
        return replaceElongated(repl_word)
    else:       
        return repl_word
def tokenize(text):
    finalTokens = []
    tokens = nltk.word_tokenize(text)
    for w in tokens:
        finalTokens.append(replaceElongated(w))
    text = " ".join(finalTokens)
    return remStopWords(text)

#Method:13 Removing stopwords
STOPWORDS = set(stopwords.words('english'))
def remStopWords(text):
    """custom function to remove the stopwords"""
    return lemmatizeWords(" ".join([word for word in str(text).split() if word not in STOPWORDS]))
#Method:14 Lemmatizing the words
lemmatizer = WordNetLemmatizer()
def lemmatizeWords(text):
    return correctSpelling(" ".join([lemmatizer.lemmatize(word) for word in text.split()]))

#Method:15 Replacing  spelling Mistakes 
def correctSpelling(text):
    for word in dic.keys():
        text = text.replace(word, dic[word])
    return text
"""spell = SpellChecker()
def correct_spellings(text):

    corrected_text = []
    s=text.split()
    misspelled_words = spell.unknown(s)
    for word in s:
        if word in misspelled_words:
            corrected_text.append(spell.correction(word))
        else:
            corrected_text.append(word)
    print("Spell" +text)
    return removeAndReplaceEmojiEmoti(" ".join(corrected_text))
"""
# Out:
# 'spell = SpellChecker()\ndef correct_spellings(text):\n\n    corrected_text = []\n    s=text.split()\n    misspelled_words = spell.unknown(s)\n    for word in s:\n        if word in misspelled_words:\n            corrected_text.append(spell.correction(word))\n        else:\n            corrected_text.append(word)\n    print("Spell" +text)\n    return removeAndReplaceEmojiEmoti(" ".join(corrected_text))\n'

# %%
#print(df.tail())
# dropping ALL duplicte values 
#df.drop_duplicates(subset ="TextComment", keep = False, inplace = True)
#print(df.tail())
output = pd.DataFrame(columns=['X', 'Y'])
df.dropna() 
x=df['Review']
y=df['Valid']
#output['X']=X.copy()
#output['Y']=y.copy()

for index, row in output.iterrows():
    x[index] = frameWork(x[index])
    print(x[index])
p
    
df.to_csv('clean1.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# something definitely wrong get touch vet take emergency vet clinic also ask vet question online one linkembarased blushing
# shaking often sign pain distress mental physical cautiously examine pup painful area contact vet
# time tell take vet
# happy new year l take tall glass bubbly please
# happy new year otis blurtit family raise glass champagne wish best new year
# happy new year one thank otis posting every morning first question look day
# happy new year everyone cheer
# happy new year l take tall glass bubbly please
# happy new year otis blurtit family raise glass champagne wish best new year
# happy new year one thank otis posting every morning first question look day
# happy new year everyone cheer
# laughing loud trying get cat screech dog howl
# sound like adelewhen sing car window rolled stereo full blast
# well kind love sing reg voice miss high note
# good gosh take chorus high scholthe music teacher told make sound mouth watermelon
# making everyone want die count good singing
# yes good singer many people said sing song checkout advertising company pakistan
# giving echo bacon bacon prefer zantac tum bicarbonate soda
# say bacon give
# count bacon love
# bring bacon crispy please happy face smiley
# bring bacon
# need b bacon
# bloated stomach day
# read bacon take bacpn
# something definitely wrong get touch vet take emergency vet clinic also ask vet question online one linkembarased blushing
# yes creepy wizkid davido olamide yce etc several song video download mp download album zip mp mp gp download free mp lil wayne
# rose taupe really pinky grey mainly greyconfusion
# teal love color
# hunter green
# lemon yellow pale blue
# ash rose
# thank ray wish
# thank ray also
# thank ray wish
# thanks wish hope
#
# l best
# sweet ray must killed cat lolconfusion kidding friend thank wish back
# thanks ray
# back ya ray happy healthy prosperous yep
# discovered weight loss journey one tell time decide going even doctor told well make want lose weight decided longer happy begun low self esteem none clothes fit make weight loss god prayer really meditate eating habit wanted change ready
# king castle decides time
# like devastated
# think
# care younger self happy proud today
# im alive
# definitley awkward shy kid happily married almost yr hey proud let alone younger
# think would impatient
# yes let honest younger self easily impressed lot naive come success failure would probably happy thing like either parent
# absolutely without doubt given superlative life
# academic research tutor reputable company offer assignment help area affordable price contact case need assignment help price low
# essay writing structure composing academic essay entail fashioning coherent pair idea debate due fact essay essentially linear feature one idea period show thought arrangement make sense individual reader properly structuring essay signifies attending reader logic focus kind essay predicts arrangement dictate advice reader need know arrangement need receive article structure fundamentally unique important claim earning although find guideline building certain traditional essay type e g comparative analysisconfusion set system answering inquiry section essay common article various sort advice frequently situated technical component segment even limited essay function number different surgery introducing debate analyzing data increasing counter argument concluding introduction decision mended place however part counterargument example happen within paragraph either freestanding segment part onset even end background material historical context biographical info summary appropriate criticism theory essential termconfusion usually appears beginning essay debut also first analytical department may possibly also appear near start specific portion truly related helpful consider different essay segment answering succession question reader might ask restricting thesis reader query thesis likely observation reality maybe arguable claim confusion first question anticipate reader would sign prof phenomenon clarified thesis true answer question must examine evidence demonstrating truth one claim really exactly demonstration part includes early essay often shortly debut essence reporting exactly seen could area got say begin producing forewarnetongue sticking cheeky playful blowing raspberry wiln take much compared third usually much lesconfusion finished essay article may lack equilibrium could see mere summary description reader may also desire understand claim thesis authentic situation corresponding challenge would thesis stand challenge counterargument exactly introduction new stuff brand new direction looking sign yet another set source affect claim making average article probably comprise atleast area phone complication responding reader complicating questionsconfusion section usually arrives keep mind article may reevaluate debate couple time depending span counter argument alone could appear almost everywhere within essay writer also want know stake claim interpretation phenomenon thing anybody beside personally question cover larger consequence one thesis enables audience comprehend essay bigger context answering essay explains unique significance although could gesture question introduction fullest reply come essay conclude abandon subscriber may experience essay incomplete worse even moot insular mapping essay structuring essay according reader logic mean assessing thesis along trusting exactly reader need learn arrangement way comprehend convinced debate evolves easy simple way map article notion published story account provide preliminary list thought enable one remind every turn reader need understanding thought essay map request predict reader may expect background information counter argument close identification main source alternate twist secondary origin stuff composing map reassure paragraph muchas section within essay writing expect key argumentative move expect composition generate try making map condition thesis sentence compose second sentence expressing vital create certain assert indicate put differently reader could know researching claim expecting answer issue finally flesh conclusion begin next sentence like convinced argue first thing reader understand say first thing reader need know title couple item evidence think produce situation start answering issue alternatively come realize first thing reader understand background detail confusion start every one subsequent sentence like next thing reader need learn state name evidence continue till mapped essay map naturally take result several preliminary response s ...
# clear introduction well defined structure logically structured body paragraph include supporting evidence academic source clear conclusion restates topic summarizes essay thesis basic essay consists three main part introduction body conclusion following format help write organize essay however flexibility important keeping basic essay format mind let topic specific assignment guide writing organization part essay introduction introduction guide reader paper introducing topic begin hook catch reader interest thesis statement thesis statement concisely state main idea argument essay set limit topic indicate organization essay body body essay support main point presented thesis point developed one paragraph supported specific detail detail include support research experience depending assignment transition transition connect paragraph thesis used within paragraph help paper flow one topic next transition one two word first next addition etc confusion one two sentence bring reader next main point conclusion conclusion brings together main point essay refers back thesis statement leaf reader final thought sense closure resolving idea brought essay may also address implication argument conclusion new topic idea undeveloped paper differ introduced citation paper incorporates research sure give credit source using text citation work cited reference bibliography page refer mla format apa format turabian format handout help detailed information get help caltutors com
# multiverse correct universe mean one differ parallel universe parallel multiverses redundant phrasing unles intersecting multiverses
# really simple answer one quote come physic stack exchange string theory multiverse theory universe one many universe exist parallel distinct universe within multiverse theory called parallel universe parallel universe description many world interpretation quantum mechanic
# e e e b c c e b e b c e e e b c c e b e b c b c e g f e
# hello fur elise one favorite song piano create video tutorial play song hand find piano note fur elise play using hand website
# hello tutorial letter note wink smirk enjoy visit website letter note letter note tutorial piano
# bela lullaby piano note hey bela lullaby note played right hand st part f f g g f f e e f f g g b flatconfusion g g x nd part b flatconfusion g e g b b c g b flatconfusion g e g b b c f g e flatconfusion e g g b f b g f e f g b f e c b g f b b flatconfusion g e g b f f c c f f b rd part g b c c b b e e g g b b c c b b e e f c c b b g g c c e e f c c b b g g c c e e th part g e e b e e g g b b g e e b th part g b c c b b e e g g b b e e f c c b b g g c c e e f c c b b g g c c e e
# piano note bela lullaby bb g e g b b c g f g eb e g f b g f e f b g b f e c b g f b b b c c f f b thats right hand play see make change version movie like one carter burwel made like one edward play movie hope like
# bela lullaby bb g e g b b c g bb g e g b b c gb g eb e g g b gb b g gb e gb b gb g b gb e c b g gb b bb g e g b gb gb c c gb gb b g b c c b b e e g g b b c c b b e e g g b b e e gb c c b b g g c c e e gb c c b b g g c c e e g e e b e e g g b b g e e b g b c c b b e e g g b b gb c c b b g g c c e e gb c c b b g g c c e e b
# hello song loot letter note laughing big grin laugh glass letter note piano like thisembarased blushing
# hi wink smirk think find website easy letter note com lot letter note piano easy tutorial beginner laughing big grin laugh glass enjoy wink smirk examplembarased blushing
# note bela lullaby c bb g e g b b c g c bb g e g b b c gb g eb e g g b gb b g gb e gb g e gb e c b g gb e c bb g e g b gb x c x gb x b g b x c x b x e x g x b x x x c x b x e x b x e x x c x b x x g x c x e x x x g e x b e x g x b x x x g e x b g b x c x b x e x g x b x x x c x b x e x b x e x x c x b x x g x c x e x x whole song right hand though
# first part bela lullaby f f g g f f e e f f g g g f f g f f e
# g g e c
# b g e g b b c b g e g b b c f g thats know
# bb g e g b b c g bb g e g b b c gb g eb e g g b gb b g gb e gb b gb g b gb e c b g gb b bb g e g b gb gb c c gb gb b g b c c b b e e g g b b c c b b e e g g b b e e gb c c b b g g c c e e gb c c b b g g c c e e g e e b e e g g b b g e e b g b c c b b e e g g b b gb c c b b g g c c e e gb c c b b g g c c e e b
# right hand bb g e g b b c g bb g e g b b c g f g eb e g left hand e g e c c g e
# g e g b b c g beginning one handed
# bsharp g e g go gconfusion b b c g bsharp g e g go gconfusion b going upconfusion b c fsharp g e g g b go upconfusion fsharp downconfusion b g fsharp e back upconfusion fsharp downconfusion b upconfusionfsharp g b upconfusion fsharp downconfusione c b g fsharp b
# c b f g g e c b f repeat
# b g e g b b c g b g e g
# b c c c b g bb f
# multiverse correct universe mean one differ parallel universe parallel multiverses redundant phrasing unles intersecting multiverses
# really simple answer one quote come physic stack exchange string theory multiverse theory universe one many universe exist parallel distinct universe within multiverse theory called parallel universe parallel universe description many world interpretation quantum mechanic
# try changing brand shampoo conditioner certain one work hair also meconfusion depend time year like right start winterconfusion hair dry even though shampoo conditioner use summer
# seemingly counterintuitive suggestion course shampooing regularly already shampoo often however shampooing regularly working would suggest trying cut shampooing shampooing strip hair natural oil scalp may produce result search po community people work might work everyone also use dry shampoo basically alcohol powder aerosol spray hair wait minute comb rids oil germ even dark dry shampoo dark hair laughing loud discovered month really improved hair situation confusion work good long hair imagine work even better shorter hair hair get dry take tiny bit coconut oil comb end hair scalpconfusion wash every day sweat get dirty otherwise shower put shower cap walmart bag like doit loud thoughconfusion
# put grease
# shampoo often use shampoo designed improve oily hair almost every brand selection like
# write one rely someone else homework
# school something search google choose favorite essay copy word hand get f go court plagiarism best way avoid dreaded f court use reliable source brain
# agree lot unnecessary information internet ordered essay website company called writemyesayonline com choose author work professional writer wrote essay right time advise ask help
# school find example internet
# first part reaction paper template usually one two paragraph long section answer question reacting introductory passage include title work author provide publishing information according instructor requirement full article explaining reaction paper available website
# artwork essay based style picture fashion illustration need angle base essay writing thought instance history fashion picture image took fashion illustration either sound adequate
# may recommend supreme essay service use feel lack idea time specialize various topic fashion one popular one
# section answer respond introductory article include title author work expert paper writer uk provide release information required teacher
# great
# may prescribe british essay writer utilize feel absence thought time expertise different point mold standout among well known one
# write one rely someone else homework
# school something search google choose favorite essay copy word hand get f go court plagiarism best way avoid dreaded f court use reliable source brain
# agree lot unnecessary information internet ordered essay website company called writemyesayonline com choose author work professional writer wrote essay right time advise ask help
# school find example internet
# first part reaction paper template usually one two paragraph long section answer question reacting introductory passage include title work author provide publishing information according instructor requirement full article explaining reaction paper available website
# artwork essay based style picture fashion illustration need angle base essay writing thought instance history fashion picture image took fashion illustration either sound adequate
# may recommend supreme essay service use feel lack idea time specialize various topic fashion one popular one
# section answer respond introductory article include title author work expert paper writer uk provide release information required teacher
# great
# may prescribe british essay writer utilize feel absence thought time expertise different point mold standout among well known one
# like devastated
# think
# care younger self happy proud today
# im alive
# definitley awkward shy kid happily married almost yr hey proud let alone younger
# think would impatient
# yes let honest younger self easily impressed lot naive come success failure would probably happy thing like either parent
# absolutely without doubt given superlative life
# chocolate day chocolate deserves one day
# pepper pot day
# uhyeah definitely keep quiet intimate friend unles friend friend
# always upset try avoid happy cost
# able gel tune wavelength could get jealous petty need stop attributing kind thing apprehension
# dialogue last mohican character madeline stowe cora munroconfusion daniel day lewis hawkeyeconfusion hawkeye father warned cora munro interupting father hawkeye chingachgok warned people like cora munro oh hawkeye said try understand cora munro hawkeye yes try make understand breed apart make sense seriously would reassure heart
# would concerned sent nude picture instead know better gut say fear
# glad kissing face would concerned
# share personal thing share personal thing bos little appeasing dating dating concerned ask problem telling sent reply sound like hiding anything text impersonai compared telephone call people often use xx convey thanks empathy especially celebration grief
# chocolate day chocolate deserves one day
# pepper pot day
# okay nek pocket knife big paper clip bend paper clip straight part stick top lock look see little like shelf sort make sure pressed take pocket knife turn lock
# movie believed need hair pin insert lock jiggle around five second hey presto door swing open enter big grin face unfortunately slightly complicated indeed burglar tend use brute force rather dexterity gain entry crude battering ram hair pin honest people successfully pick kind secure lock locksmith need something called skeleton key rather whole bunch skeleton key lock open case modern lock undesigned easily picked like day old certain car would start key corned beef tin
# happened stumble across response could resist opportunity reply sorry answer lack insight basic knowledge regarding lock smithing guess never witnessed lock smith manipulating secured lock lieu key might surprised learn lock smith actually pick lock using lock pick however unnecessarily need lock smith pick lock lot patience considerable practice anyone learn pick lock without formal training received lock smith case associated tool trade may differ required instance given scenario tool may needed credit card using credit card however compress locking mechanism would technically considered picking lock rather deemed breaking entering
# pick lock locksmith firm need look locksmith company online see feedback got even simply search locksmith san francisco
# pick lock eagle locksmith
# pick lock eagle locksmith
# legally
# lock picking defined manipulation lock component open lock without normal key therefore pick lock successfully one must understand principle lock key standard deadbolt lock consists pin tumbler rotated key open lock lock similar concept learning method lock picking serve well buy practice lock get standard five pin deadbolt lock disassembled remove first pin closest front lock way pick door lock maneuvering pin tumbler sheer line sheer line mechanism measurement tell lock okay open key lift first pin tumble sheer line groove key already entering gap second pin fashion pick tool pick tool made straightened paperclip flat end hairpin tiny flathead screwdriver also fashioned straight safety pin industrial staple turn lock upside watch gravity pull pin show insert pick apply gentle pressure downward hit sheer line plug turn student know feel pressure needed release pin turn lock right side practice one pin mastered add another pin back lock close lock try first pin released second pin differ engaged keep practicing adding pin five back lock concentrated focus lock picking mastery technique take little hour pin lock sturdier pick need one never know lock need picked however mastering art lock picking may get individual back car home without incurring expense calling locksmith
# borrow new one mother
# best way use key
# best way cut fave use shot gun bam note see lock anymore
# buy pocket knife get paper clip put paper top part lock pocket knife bottom part
# uh would need happen anything
# usually respond question ill let time occasion despite convenient may sound losing weight quickly would probably feel rewarding long like short lived impulse happens turn feeling take process duration plan feel happier accomplish knowing planned determination result properly long routeconfusion also build sense control result progress lot people told felt feeling quickly rushing weight goal like talking think want lose pound find way urgently cheat probably im sure possible though maybe could accept easy route truth stuff hear online lie unsafe scam id say method hear online false heard lot tried lose weight ironically im warning b seen could imagine someone searching intentionally find im sure everyone disagree advice besides course ask doctor thought response
# salad exercise
# talk doctor please unmake anything dangerous
# oh ho person gain pound quickly
# gain quickly expect lose quickly proper way eat well balanced well portioned diet stay hydrated get least hour sleep also get minute exercise everyday walk free easy minute one time two minute walk three minute walk
# create calorie deficit figure consuming daily reduce calorie maintaining weight gaining weight add least step day lose weight since gain overnight expect lose overnight
# urgent week free membership aps prize jackpot txt wortongue sticking cheeky playful blowing raspberry claim c lcltd pobox ldnwarw
# still pretty weak today bad day
# hey forget mine possession property mm childish smile
# excellent thought misundrstud frntongue sticking cheeky playful blowing raspberry knw hate bt day wen u l knw truth u l hate urselfrown sad andry pouting gnhapy face smiley
# hey congrats u id luv ive go home
# dear call
# xy trying smth eat already havent
# urgent please call landline aps cash luxury canary island holiday await collection c sae po box mxy pm
# dono gene something
# xmas iscoming ur awarded either aps cd gift voucher free entry r aps weekly draw txt music tnc
# alex say ok ok
# coming funeral home
# darling sister school resuming minimum wait period reaply take care
# l hand phone chat wit
# well good morning mr hows london treatin ya treacle
# make tonight
# time come tomorrow
# lt gt buck bank fee fixed better call bank find
# tell quite long co finish film yet
# pls ask macho much budget bb bold co saw new one lt gt dollar
# hi missed call mumhas bendroping red wine theplace adres
# ill min look
# leave
# coming back thursday yay gon na ok get money cheer oh yeah everything alright hows school call work
# jolly good way give ticket sat eve speak x
# yeah thinking
# k khapy face smileyi going tirunelvali week see uncle already spend amount taking dress want money give feb
# got ur favorite oyster n got favorite sashimi ok lar dun say already wait ur stomach start rumbling
# sister going earn da
# get official england poly ringtone color flag yer mobile tonight game text tone flag optout txt eng stop box wx aps
# hahahause brain dear
# jus finish watching tv u
# k information back parent place south tampa might need deal somewhere else
# good morning love go sleep wish great day full feeling better opportunity last thought babe love kiss
# kothi print marandratha
# havent got da topic yet rite
# ok problem yup going sch rem correctly
# thanks keep mind
# aah bless arm
# dear sir salam alaikum pride pleasure meeting today tea shop pleased send contact number qatar rakhesh indian pls save number respectful regard
# get life n boy walking park gal hold ur hand boy think would run away gal jst wana c feel walking heaven princegnhapy face smiley
# make happy
# wishing wonderful week
# sweet heart
# sir waiting letter
# dude im longer pisces im aquarius
# x course yr message messenger lik r sending
# think steyn surely get one wickethapy face smiley
# neither sterm voice studying fine sure thing resolved tho anyway fab hols
# garbage bag egg jam bread hanaford wheat chex
# humility almost lt gt year old differ takin money kid supposed deal stuff grownup stuff tell
# sound better evening im costume im sure time finish tomorrow txt end
# birthday feb lt gt da
# wan na gym
# like would jerk
# awake snow
# course make stink
# r subscribed textcomp wkly comp st wk free question follows subsequent wks charged p msg unsubscribe txt stop custcare
# go opening room til thanksgiving without upcharge
# guy planning coming
# wat
# parent kidz friend n colleague screaming surprise waiting sofa naked
# sir hr trip bus last week another audition next wednesday think might drive time
# thought put back box
# home
# one interested may business plan
# yup paragon havent decided whether cut yet
# good morning princess great day
# guai aoe shd haf seen naughty aoe free today go jogging
# aiyo co sm neva reply wait reply lar tot havent finish ur lab wat
# living simple loving also simple laughing simple winning simple simple difficult confusion happy face smiley
# tell something thats okay
# ok
# hm shal bring bottle wine keep u amused joking still bring bottle red white see tomorrow
# ur face test lt gt confusion select number tell ur face astrology waiting quick reply
# hey iouri gave number wylie ryan friend
# yep get program slacking
# inside oficestil filling form know leave
# think mentor percent sure
# call send girl erotic ecstacy p min stop text call nat rateconfusion
# camera awarded sipix digital camera call landline delivery within day
# aps xmas reward waiting computer randomly picked loyal mobile customer receive aps reward call
# trying figure suppose see couple different people week said would get together rise date
# important message final contact attempt important message waiting customer claim dept expires call
# hi mom might back later lt gt
# dating two started sent text talk sport radio last week connection think coincidence
# lol oh got friend dog
# ok problem frm wats matter
# k head min see
# konw waht rael friendship im gving yuo exmpel jsut ese tihs msg evrey spleing tihs msg wrnog bt sitl yuo raed wihtuot ayn mitsake godnight amp nice slepswet dream
# cant pick phone right pls send message
# want leave barely stay sane fighting constantly helping
# current leading bid pause auction send customer care
# free entry grprizes wkly comp chance win latest nokia psp aps cash every wk txt great http
# somebody set website play hold em using eve online spacebucks
# sunny california weather cool
# new message call
# make squeezed lt gt buck dad
# good day pray remove teeth painful maintaining stuff
# babe hope ok shit night sleep fell asleep ia knackered ia dreading work tonight thou upto tonight x
# friend help u problem give stupid suggestion land u another problem help u forgt previous problem
# work please call
# gentle baby soon taking lt gt inch deep inside tight pussy
# much fight good nite
# ok ok okthenwhats ur today plan
# nt joking seriously told
# watching ajith film ah
# ooh forgot tell get yovile phone
# done handed know mega shop asda count celebration thats
# dont know exactly could ask chechi
# duno lei shd b driving lor co go sch hr oni
# want custom officer discount oh
# necessarily respectful
# hi hope good day better night
# apparently bfs carly quick
# hard true much show amp express love someonethat much hurt leave get seperated e aeur ud evening
# babe think got ur brolly left english wil bring mrw luv franx
# hi babe thanks coming even though didnt go well wanted bed hope see soon love kiss xxx
# gd got free ice cream oso wan
# pls give prometazine syrup ml lt gt min later feed
# many day since
# dear angry busy dear
# yup msg tat yijue tot group mate co meeting today mah askin leaving earlier wat mah co mayb haf walk v far
# pub
# first time everything happy face smiley
# daddy shu shu looking u wan tell u singapore wat
# ask meeting da ge tmr nite
# gr handle victoria island traffic plus album due
# nite nite pocay wocay luv n e thing eva promise ring morowx
# east coast
# get chicken broth want ramen unles ignore
# slave want take picture today bright light cell phone bright light
# nope forgot show next week
# really master
# bruce amp fowler mom car park long storyconfusion
# dont know oh hopefully month
# hi elaine today meeting confirmed
# ok ksry knw sivatats askd
# sorry call later
# horrible gal knew dat going wif yest n still come n ask
# otherwise part time job na tuition
# oh yeah diet flew window
# santa calling would little one like call santa xmas eve call book time
# didnt complete gist oh
# er yeah b sorry tell pub cafe sit come wen
# make time tonight whenever cool text whenever around
# default attention
# thanx lot ur help
# gon na way specific
# jesus armand really trying tell everybody find
# wif buying tix lar
# mode men left
# slow using biola fne
# youdoing later sar xxx
# hey booked lesson sun liao
# thank generally date brothas
# way make sure get train worc foregate street shrub hill fun night x
# thought would get watch co thats kind thing getanth love much
# guaranteed award maybe even aps cash claim ur award call free confusion legitimat efrefone number wat think
# good morning repair shop reason hour
# fine got enough bud last night least
# back good journey let know need receipt shal tell like pendent
# take away money worry
# aight pick open tonight
# latest news police station toilet stolen cop nothing go
# sac need carry onhapy face smiley
# sing hu think also important find someone female know place well preferably citizen also smart help navigate even thing like choosing phone plan require guidance doubt ask especially girl
# hello wats talk email address
# except there chick huge boob
# im wondering right
# wishing beautiful day moment revealing even thing keep smiling enjoy
# sparkling shopping break per person call visit
# arun transfr amt
# sorry call later
# hear loud scream lt gt minute cause gyno shoving thing belong skeptical annoyed undecided uneasy hesitant
# december mobile mths entitled update latest color camera mobile free call mobile update co free
# ok thk got wan come wat
# txt call claim reward hour talk time use phone subscribegbp mnth inc hr stop txtstop
# goin nite
# treasure every moment spend together
# shal bring u bottle wine keep u amused joking iaeur l bring one anyway
# http tm widelive com index wml id ada first truea c c ringtonea
# get garden ready summer free selection summer bulb seed worth aps scotsman saturday stop go notxt co uk
# urgent last weekend draw show aps cash spanish holiday call claim c rstm sw s pm
# ok lor
# thought slide enough
# yup
# well obviously people cool college life went home sad cry
# ok lor reaching message
# mummy boy good bad positive negative mummy made wait hm
# dhoni luck win big title winhapy face smiley
# yes princess want please every night wish command
# today sundaysunday holidayso work
# probably lt gt
# really hope work doesnt get stressful great day
# seen back holby
# shal call dear food
# urgent trying contact last weekend draw show aps prize guaranteed call claim code k valid hr p pm
# li hai bored da lecturer repeating last week stuff waste time
# picking various point going yeovil motor project hour take home max easy
# also fuck family going rhode island wherever fuck leaving alone week new bong gt frown sad andry pouting
# ofcourse also upload song
# p per min call germany bt line p per min check planetalkinstant com info c text stop opt
# k sent
# oh thanks loti already bought egg
# k sent
# studying sch going home anyway b going sch later
# marvel mobile play official ultimate spider man game aps confusion ur mobile right text spider game l send free ball wallpaper
# think rule tamilnaduthen tough people
# cool shal go see go tip anyway home got something drop later let go town tonight maybe mum take u
# good afternoon love go day sleep hope well boytoy think
# yes trust buy new stuff soon possible try
# sm service inclusive text credit pls goto login qxj unsubscribe stop extra charge help comuk cm ae
# wake gt frown sad andry pouting
# get step outa way congrats
# love one law make happy person love way friendship one law never make ur friend feel alone alive gud night
# private account statement show un redeemed point call identifier code expires
# apo moka player
# perhaps much easy give account identification tomorrow uni
# wait msg lt gt min
# told tell stupid hear wont tell anything dad called brother spoken
# god love limit god grace measure god power boundary may god endless blessing always ur life gud ni
# want inside every night
# machan go gym tomorrow wil come late godnight
# laughing loud mad first woke gave
# went project center
# itaeur reassuring crazy world
# making dinner
# yes please leave lt gt lt gt leave
# oh okie lorwe go sat
# great role model giving much really wish day miracle god reason everything must say wish knew dont looked since young still great day
# ya referin mei ex wat ah waitin treat somebody shld b rich liaoso gd den dun work frm tmr onwards
# mile smile r made frm letter know difference smile ur face keep happy even though mile away u happy face smileykep smiling good nyt
# way put skip right outside front house see house pull
# pls send company name saibaba colany
# dont want hear anything
# big chic common declare
# thats cool want please
# going join tomorrow
# awarded sipix digital camera call landline delivery within day c box mbp yr warranty pm p pap
# want tell bad feel basically time text lately need drug
# private account statement show un redeemed point call identifier code expires
# total disappointment texted craziest shit got frown sad andry pouting
# effect irritation ignore
# one
# think tantrum finished yeah point
# compliment away system side
# happened adventuring
# hey chief give bell get need talk royal visit st june
# ok another number
# know thinkin malaria relax child cant handle malaria would worse gastroenteritis take enough replace loss temp reduce give malaria med vomit self limiting illness mean day completely stop
# aiyah ok wat long got improve already wat
# want explicit sex sec ring cost p min gsex pobox wcn xx
# disbelieve attached seeing every day know best get babe go teach class midnight
# slepingand surfing
# asked mobile chatlines inclu free min india cust servs sed yes ler got mega bill dont giv shit bailiff due day aps want aps
# yeah jus rite
# armand say get as epsilon
# still havent got urself jacket ah
# taking derek amp taylor walmart back time done leave mouse desk text priscila ready
# hi durban still number
# ic lota childporn car
# contract mobile mnths latest motorola nokia etc free double min text orange tariff text yes callback remove record
# trying weekend v
# know wot people wear shirt jumper hat belt know r crib
# cool time think get
# wen get spiritual deep great
# safe trip nigeria wish happiness soon company share moment
# hahahause brain dear
# well keep mind got enough gas one round trip barring sudden influx cash
# yeh indian nice tho kane bit shud go drink sometime soon mite hav go da work laugh soon love pete x x
# yes texted pshewmising much
# meant calculation lt gt unit lt gt school really expensive started practicing accent important decided year dental school nmde exam
# sorry call later
# next lt gt hour ima flip shit
# anything lor juz u lor
# get dump heap mom decided come lowes boring
# ok lor sony ericson salesman ask shuhui say quite gd use considering
# ard like dat lor
# wait til least wednesday see get
# huh lei
# reminder get pound free call credit detail great offer pls reply text valid name house postcode
# nd time tried contact u aps pound prize claim easy call p per minute bt national rate
# b going esplanade fr home
# pity mood soany suggestion
# guy bitching acted like would interested buying something else next week gave u free
# rofl true name

# %%
 
files.download('clean1.csv')

# %%
# Out:
#      <input type="file" id="files-7e6de590-3766-4962-a91a-127c0cd5d68b" name="files[]" multiple disabled />
#      <output id="result-7e6de590-3766-4962-a91a-127c0cd5d68b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving clean.csv to clean (2).csv
#    Unnamed: 0  Valid                                             Review
# 0           0    1.0  something is definitely wrong get in touch wit...
# 1           1    1.0  shaking is most often a sign of pain distress ...
# 2           2    0.0  you had time to tell us about it and not take ...
# 3           3    0.0  happy new year to be i l take a tall glass of ...
# 4           4    0.0  happy new year otis and blurtit family i raise...

# %%
df1.head()
# Out:
#    Unnamed: 0  Valid                                             Review
# 0           0    1.0  something is definitely wrong get in touch wit...
# 1           1    1.0  shaking is most often a sign of pain distress ...
# 2           2    0.0  you had time to tell us about it and not take ...
# 3           3    0.0  happy new year to be i l take a tall glass of ...
# 4           4    0.0  happy new year otis and blurtit family i raise...

# %%
output = pd.DataFrame(columns=['X', 'Y'])
df1.dropna() 
x=df1['Review']
y=df1['Valid']
output['X']=x.copy()
output['Y']=y.copy()
#pd.options.display.float_format = '{:,.0f}'.format
output['Y'] = output['Y'].fillna(0.0).astype(int)
output.head()
# Out:
#                                                    X  Y
# 0  something is definitely wrong get in touch wit...  1
# 1  shaking is most often a sign of pain distress ...  1
# 2  you had time to tell us about it and not take ...  0
# 3  happy new year to be i l take a tall glass of ...  0
# 4  happy new year otis and blurtit family i raise...  0

# %%
# !pip install glove_python
# Out:
# Collecting glove_python
#   Downloading https://files.pythonhosted.org/packages/3e/79/7e7e548dd9dcb741935d031117f4bed133276c2a047aadad42f1552d1771/glove_python-0.1.0.tar.gz (263kB)
#      |████████████████████████████████| 266kB 9.1MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from glove_python) (1.17.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from glove_python) (1.3.3)
# Building wheels for collected packages: glove-python
#   Building wheel for glove-python (setup.py) ... done
#   Created wheel for glove-python: filename=glove_python-0.1.0-cp36-cp36m-linux_x86_64.whl size=702679 sha256=0c9dd55950a0405e391c1cb5aa5412e9963031b9ae068d44a1a7957ad7e063ad
#   Stored in directory: /root/.cache/pip/wheels/88/4b/6d/10c0d2ad32c9d9d68beec9694a6f0b6e83ab1662a90a089a4b
# Successfully built glove-python
# Installing collected packages: glove-python
# Successfully installed glove-python-0.1.0

# %%
# !pip install sklearn
# !pip install zeugma
from zeugma.embeddings import EmbeddingTransformer
# Out:
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn) (0.22)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (0.14.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.17.4)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.3.3)
# Collecting zeugma
#   Downloading https://files.pythonhosted.org/packages/37/06/987f0c591e4f46fc31446d541d17d63981394f099c455955680dfe7bd980/zeugma-0.46.tar.gz
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from zeugma) (1.17.4)
# Requirement already satisfied: Cython>=0.27.3 in /usr/local/lib/python3.6/dist-packages (from zeugma) (0.29.14)
# Requirement already satisfied: pandas>=0.20.3 in /usr/local/lib/python3.6/dist-packages (from zeugma) (0.25.3)
# Requirement already satisfied: gensim>=3.5.0 in /usr/local/lib/python3.6/dist-packages (from zeugma) (3.6.0)
# Requirement already satisfied: scikit_learn>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from zeugma) (0.22)
# Requirement already satisfied: tensorflow>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from zeugma) (1.15.0)
# Requirement already satisfied: keras>=2.1.3 in /usr/local/lib/python3.6/dist-packages (from zeugma) (2.2.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.3->zeugma) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.3->zeugma) (2.6.1)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim>=3.5.0->zeugma) (1.12.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim>=3.5.0->zeugma) (1.3.3)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from gensim>=3.5.0->zeugma) (1.9.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit_learn>=0.19.1->zeugma) (0.14.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->zeugma) (0.1.8)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->zeugma) (1.1.0)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->zeugma) (0.2.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->zeugma) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->zeugma) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->zeugma) (1.11.2)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->zeugma) (0.8.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->zeugma) (0.33.6)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->zeugma) (1.15.0)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->zeugma) (1.15.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->zeugma) (1.0.8)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->zeugma) (3.10.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->zeugma) (1.15.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.5.0->zeugma) (0.8.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.3->zeugma) (2.8.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.3->zeugma) (3.13)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim>=3.5.0->zeugma) (2.21.0)
# Requirement already satisfied: boto>=2.32 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim>=3.5.0->zeugma) (2.49.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim>=3.5.0->zeugma) (1.10.40)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow>=1.5.0->zeugma) (42.0.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow>=1.5.0->zeugma) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow>=1.5.0->zeugma) (0.16.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim>=3.5.0->zeugma) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim>=3.5.0->zeugma) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim>=3.5.0->zeugma) (2019.11.28)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim>=3.5.0->zeugma) (1.24.3)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim>=3.5.0->zeugma) (0.2.1)
# Requirement already satisfied: botocore<1.14.0,>=1.13.40 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim>=3.5.0->zeugma) (1.13.40)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim>=3.5.0->zeugma) (0.9.4)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.14.0,>=1.13.40->boto3->smart-open>=1.2.1->gensim>=3.5.0->zeugma) (0.15.2)
# Building wheels for collected packages: zeugma
#   Building wheel for zeugma (setup.py) ... done
#   Created wheel for zeugma: filename=zeugma-0.46-cp36-none-any.whl size=8611 sha256=cee3ce6c450af704a6a4dd069bdfc48bcdc48b20259e06b786937d4a795ff993
#   Stored in directory: /root/.cache/pip/wheels/49/ce/d3/22bc15de9112558b220d9dba3bfcd7d9ad0d8cc4d44d3e7813
# Successfully built zeugma
# Installing collected packages: zeugma
# Successfully installed zeugma-0.46
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pkg_resources/__init__.py in _dep_map(self)
#    3020         try:
# -> 3021             return self.__dep_map
#    3022         except AttributeError:
#
# /usr/local/lib/python3.6/dist-packages/pkg_resources/__init__.py in __getattr__(self, attr)
#    2814         if attr.startswith('_'):
# -> 2815             raise AttributeError(attr)
#    2816         return getattr(self._provider, attr)
#
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pkg_resources/__init__.py in _parsed_pkg_info(self)
#    3011         try:
# -> 3012             return self._pkg_info
#    3013         except AttributeError:
#
# /usr/local/lib/python3.6/dist-packages/pkg_resources/__init__.py in __getattr__(self, attr)
#    2814         if attr.startswith('_'):
# -> 2815             raise AttributeError(attr)
#    2816         return getattr(self._provider, attr)
#
# AttributeError: _pkg_info
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-186-47963e5c2f2d> in <module>()
#       1 get_ipython().system('pip install sklearn')
#       2 get_ipython().system('pip install zeugma')
# ----> 3 from zeugma.embeddings import EmbeddingTransformer
#
# /usr/local/lib/python3.6/dist-packages/zeugma/__init__.py in <module>()
#      11 from .keras_transformers import TextsToSequences, Padder  # noqa
#      12
# ---> 13 __version__ = get_distribution("zeugma").version
#
# /usr/local/lib/python3.6/dist-packages/pkg_resources/__init__.py in get_distribution(dist)
#     479         dist = Requirement.parse(dist)
#     480     if isinstance(dist, Requirement):
# --> 481         dist = get_provider(dist)
#     482     if not isinstance(dist, Distribution):
#     483         raise TypeError("Expected string, Requirement, or Distribution", dist)
#
# /usr/local/lib/python3.6/dist-packages/pkg_resources/__init__.py in get_provider(moduleOrReq)
#     355     """Return an IResourceProvider for the named module or requirement"""
#     356     if isinstance(moduleOrReq, Requirement):
# --> 357         return working_set.find(moduleOrReq) or require(str(moduleOrReq))[0]
#     358     try:
#     359         module = sys.modules[moduleOrReq]
#
# /usr/local/lib/python3.6/dist-packages/pkg_resources/__init__.py in require(self, *requirements)
#     898         included, even if they were already activated in this working set.
#     899         """
# --> 900         needed = self.resolve(parse_requirements(requirements))
#     901
#     902         for dist in needed:
#
# /usr/local/lib/python3.6/dist-packages/pkg_resources/__init__.py in resolve(self, requirements, env, installer, replace_conflicting, extras)
#     792
#     793             # push the new requirements onto the stack
# --> 794             new_requirements = dist.requires(req.extras)[::-1]
#     795             requirements.extend(new_requirements)
#     796
#
# /usr/local/lib/python3.6/dist-packages/pkg_resources/__init__.py in requires(self, extras)
#    2734     def requires(self, extras=()):
#    2735         """List of Requirements needed for this distro if `extras` are used"""
# -> 2736         dm = self._dep_map
#    2737         deps = []
#    2738         deps.extend(dm.get(None, ()))
#
# /usr/local/lib/python3.6/dist-packages/pkg_resources/__init__.py in _dep_map(self)
#    3021             return self.__dep_map
#    3022         except AttributeError:
# -> 3023             self.__dep_map = self._compute_dependencies()
#    3024             return self.__dep_map
#    3025
#
# /usr/local/lib/python3.6/dist-packages/pkg_resources/__init__.py in _compute_dependencies(self)
#    3030         reqs = []
#    3031         # Including any condition expressions
# -> 3032         for req in self._parsed_pkg_info.get_all('Requires-Dist') or []:
#    3033             reqs.extend(parse_requirements(req))
#    3034
#
# /usr/local/lib/python3.6/dist-packages/pkg_resources/__init__.py in _parsed_pkg_info(self)
#    3012             return self._pkg_info
#    3013         except AttributeError:
# -> 3014             metadata = self.get_metadata(self.PKG_INFO)
#    3015             self._pkg_info = email.parser.Parser().parsestr(metadata)
#    3016             return self._pkg_info
#
# /usr/local/lib/python3.6/dist-packages/pkg_resources/__init__.py in get_metadata(self, name)
#    1418             return ""
#    1419         path = self._get_metadata_path(name)
# -> 1420         value = self._get(path)
#    1421         if six.PY2:
#    1422             return value
#
# /usr/local/lib/python3.6/dist-packages/pkg_resources/__init__.py in _get(self, path)
#    1614
#    1615     def _get(self, path):
# -> 1616         with open(path, 'rb') as stream:
#    1617             return stream.read()
#    1618
#
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/local/lib/python3.6/dist-packages/scikit_learn-0.21.3.dist-info/METADATA'

# %%
def BOW_vectorization():
    count_vectorizer = CountVectorizer()
    
    bow_text = count_vectorizer.fit_transform(output['X'].values.astype('U'))
    bow_feature_names = count_vectorizer.get_feature_names()
    #visualizations().plot_frequency_distribution(bow_text, bow_feature_names)
    X = pd.DataFrame(bow_text.toarray(), columns = bow_feature_names)
    Y = output['Y']
    #visualizations().plot_TSNE_distribution(bow_text, Y)
    return X, Y

def TFIDF_vectorization():
    tfidf_vectorizer = TfidfVectorizer(max_features = 5500)
    tfidf_text = tfidf_vectorizer.fit_transform(output['X'].values.astype('U'))
    tfidf_feature_names = tfidf_vectorizer.get_feature_names()
    #visualizations().plot_frequency_distribution(tfidf_text, tfidf_feature_names)
    X = pd.DataFrame(tfidf_text.toarray(), columns = tfidf_feature_names)
    Y = output['Y']
    #visualizations().plot_TSNE_distribution(tfidf_text, Y)
    return X, Y

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
X1, Y1 =BOW_vectorization()
train, Xtest, Ytrain, Ytest = train_test_split(X1, Y1, test_size = 0.2, random_state = 12)

# %%
import numpy; print("NumPy", numpy.__version__)
import scipy; print("SciPy", scipy.__version__)
import sklearn; print("Scikit-Learn", sklearn.__version__)
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.metrics import (accuracy_score, roc_curve, auc, roc_auc_score, 
                             confusion_matrix, classification_report)
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import GridSearchCV
# Out:
# NumPy 1.17.4
# SciPy 1.3.3
# Scikit-Learn 0.21.3
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-200-f0477cd24219> in <module>()
#       2 import scipy; print("SciPy", scipy.__version__)
#       3 import sklearn; print("Scikit-Learn", sklearn.__version__)
# ----> 4 from sklearn.tree import DecisionTreeClassifier
#       5 from sklearn.ensemble import RandomForestClassifier, VotingClassifier
#       6 from sklearn.neighbors import KNeighborsClassifier
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/__init__.py in <module>()
#       4 """
#       5
# ----> 6 from ._classes import BaseDecisionTree
#       7 from ._classes import DecisionTreeClassifier
#       8 from ._classes import DecisionTreeRegressor
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/_classes.py in <module>()
#      33 from ..utils import check_array
#      34 from ..utils import check_random_state
# ---> 35 from ..utils.validation import _check_sample_weight
#      36 from ..utils import compute_sample_weight
#      37 from ..utils.multiclass import check_classification_targets
#
# ImportError: cannot import name '_check_sample_weight'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
